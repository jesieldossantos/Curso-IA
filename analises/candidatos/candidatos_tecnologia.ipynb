# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df_candidatos_tecnologia1 = pd.read_csv('./candidatos_tecnologia_1.csv')
df_candidatos_tecnologia2 = pd.read_csv('./candidatos_tecnologia_2.csv')
df_candidatos_tecnologia3 = pd.read_csv('./candidatos_tecnologia_3.csv')

# %%
df_candidatos_tecnologia1.head()
# Out:
#    id_candidato data_inscricao         nome     genero estado  idade  \
# 0             1     2022-04-13  Candidato_1  Masculino     SP   23.0
# 1             2     2023-03-12  Candidato_2  Masculino     MG    NaN
# 2             3     2022-09-28  Candidato_3  Masculino     DF   61.0
# 3             4     2022-04-17  Candidato_4      Outro     PE   28.0
# 4             5     2022-03-13  Candidato_5      Outro     RS   19.0
#
#        formacao   area_atuacao  experiencia_anos  certificacoes   idiomas  \
# 0      Mestrado     Financeiro               4.8            3.0  Espanhol
# 1  Ensino Médio  Administração               5.5            3.0   Francês
# 2     Doutorado  Administração               6.3            3.0  Espanhol
# 3           NaN     Engenharia               2.7            2.0  Espanhol
# 4  Ensino Médio     Tecnologia               7.4            1.0    Nenhum
#
#    pretensao_salarial  salario_vaga disponibilidade_viagem  \
# ...

# %%
df_candidatos_tecnologia1.tail()
# Out:
#      id_candidato data_inscricao            nome     genero estado  idade  \
# 995           996     2023-10-04   Candidato_996  Masculino     MG   60.0
# 996           997     2023-08-19   Candidato_997        NaN     CE   56.0
# 997           998     2022-11-17   Candidato_998        NaN     RS   34.0
# 998           999     2022-11-15   Candidato_999   Feminino     PR   37.0
# 999          1000     2023-09-05  Candidato_1000  Masculino     RJ   41.0
#
#          formacao      area_atuacao  experiencia_anos  certificacoes  \
# 995      Mestrado  Recursos Humanos               5.4            2.0
# 996     Doutorado        Engenharia               8.3            3.0
# 997     Doutorado         Marketing               NaN            1.0
# 998  Ensino Médio        Tecnologia               3.5            1.0
# 999  Ensino Médio        Tecnologia               4.5            2.0
#
#       idiomas  pretensao_salarial  salario_vaga disponibilidade_viagem  \
# ...

# %%
df_candidatos_tecnologia1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id_candidato             1000 non-null   int64
#  1   data_inscricao           1000 non-null   object
#  2   nome                     900 non-null    object
#  3   genero                   900 non-null    object
#  4   estado                   900 non-null    object
#  5   idade                    900 non-null    float64
#  6   formacao                 900 non-null    object
#  7   area_atuacao             900 non-null    object
#  8   experiencia_anos         900 non-null    float64
#  9   certificacoes            900 non-null    float64
#  10  idiomas                  900 non-null    object
#  11  pretensao_salarial       900 non-null    float64
#  12  salario_vaga             900 non-null    float64
#  13  disponibilidade_viagem   900 non-null    object
# ...

# %%
df_candidatos_tecnologia2.head()
# Out:
#    codigo_candidato data_cadastro nome_completo       sexo  uf  faixa_etaria  \
# 0                 1    2022-04-13   Candidato_1  Masculino  SP          23.0
# 1                 2    2023-03-12   Candidato_2  Masculino  MG           NaN
# 2                 3    2022-09-28   Candidato_3  Masculino  DF          61.0
# 3                 4    2022-04-17   Candidato_4      Outro  PE          28.0
# 4                 5    2022-03-13   Candidato_5      Outro  RS          19.0
#
#   nivel_educacional setor_profissional  tempo_experiencia  qtd_certificacoes  \
# 0          Mestrado         Financeiro                4.8                3.0
# 1      Ensino Médio      Administração                5.5                3.0
# 2         Doutorado      Administração                6.3                3.0
# 3               NaN         Engenharia                2.7                2.0
# 4      Ensino Médio         Tecnologia                7.4                1.0
#
# ...

# %%
df_candidatos_tecnologia2.tail()
# Out:
#      codigo_candidato data_cadastro   nome_completo       sexo  uf  \
# 995               996    2023-10-04   Candidato_996  Masculino  MG
# 996               997    2023-08-19   Candidato_997        NaN  CE
# 997               998    2022-11-17   Candidato_998        NaN  RS
# 998               999    2022-11-15   Candidato_999   Feminino  PR
# 999              1000    2023-09-05  Candidato_1000  Masculino  RJ
#
#      faixa_etaria nivel_educacional setor_profissional  tempo_experiencia  \
# 995          60.0          Mestrado   Recursos Humanos                5.4
# 996          56.0         Doutorado         Engenharia                8.3
# 997          34.0         Doutorado          Marketing                NaN
# 998          37.0      Ensino Médio         Tecnologia                3.5
# 999          41.0      Ensino Médio         Tecnologia                4.5
#
#      qtd_certificacoes idioma_principal  salario_esperado  salario_oferecido  \
# ...

# %%
df_candidatos_tecnologia2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   codigo_candidato    1000 non-null   int64
#  1   data_cadastro       1000 non-null   object
#  2   nome_completo       900 non-null    object
#  3   sexo                900 non-null    object
#  4   uf                  900 non-null    object
#  5   faixa_etaria        900 non-null    float64
#  6   nivel_educacional   900 non-null    object
#  7   setor_profissional  900 non-null    object
#  8   tempo_experiencia   900 non-null    float64
#  9   qtd_certificacoes   900 non-null    float64
#  10  idioma_principal    900 non-null    object
#  11  salario_esperado    900 non-null    float64
#  12  salario_oferecido   900 non-null    float64
#  13  aceita_viagem       900 non-null    object
#  14  aceita_mudanca      900 non-null    object
# ...

# %%
df_candidatos_tecnologia3.head()
# Out:
#    ID DO CANDIDATO DATA DE INSCRIÇÃO NOME COMPLETO     GÊNERO ESTADO  IDADE  \
# 0                1        2022-04-13   Candidato_1  Masculino     SP   23.0
# 1                2        2023-03-12   Candidato_2  Masculino     MG    NaN
# 2                3        2022-09-28   Candidato_3  Masculino     DF   61.0
# 3                4        2022-04-17   Candidato_4      Outro     PE   28.0
# 4                5        2022-03-13   Candidato_5      Outro     RS   19.0
#
#   FORMAÇÃO ACADÊMICA ÁREA DE ATUAÇÃO  ANOS DE EXPERIÊNCIA  CERTIFICAÇÕES  \
# 0           Mestrado      Financeiro                  4.8            3.0
# 1       Ensino Médio   Administração                  5.5            3.0
# 2          Doutorado   Administração                  6.3            3.0
# 3                NaN      Engenharia                  2.7            2.0
# 4       Ensino Médio      Tecnologia                  7.4            1.0
#
# ...

# %%
df_candidatos_tecnologia3.tail()
# Out:
#      ID DO CANDIDATO DATA DE INSCRIÇÃO   NOME COMPLETO     GÊNERO ESTADO  \
# 995              996        2023-10-04   Candidato_996  Masculino     MG
# 996              997        2023-08-19   Candidato_997        NaN     CE
# 997              998        2022-11-17   Candidato_998        NaN     RS
# 998              999        2022-11-15   Candidato_999   Feminino     PR
# 999             1000        2023-09-05  Candidato_1000  Masculino     RJ
#
#      IDADE FORMAÇÃO ACADÊMICA   ÁREA DE ATUAÇÃO  ANOS DE EXPERIÊNCIA  \
# 995   60.0           Mestrado  Recursos Humanos                  5.4
# 996   56.0          Doutorado        Engenharia                  8.3
# 997   34.0          Doutorado         Marketing                  NaN
# 998   37.0       Ensino Médio        Tecnologia                  3.5
# 999   41.0       Ensino Médio        Tecnologia                  4.5
#
#      CERTIFICAÇÕES    IDIOMA  PRETENSÃO SALARIAL  SALÁRIO DA VAGA  \
# ...

# %%
df_candidatos_tecnologia3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID DO CANDIDATO          1000 non-null   int64
#  1   DATA DE INSCRIÇÃO        1000 non-null   object
#  2   NOME COMPLETO            900 non-null    object
#  3   GÊNERO                   900 non-null    object
#  4   ESTADO                   900 non-null    object
#  5   IDADE                    900 non-null    float64
#  6   FORMAÇÃO ACADÊMICA       900 non-null    object
#  7   ÁREA DE ATUAÇÃO          900 non-null    object
#  8   ANOS DE EXPERIÊNCIA      900 non-null    float64
#  9   CERTIFICAÇÕES            900 non-null    float64
#  10  IDIOMA                   900 non-null    object
#  11  PRETENSÃO SALARIAL       900 non-null    float64
#  12  SALÁRIO DA VAGA          900 non-null    float64
#  13  DISPONÍVEL PARA VIAGENS  900 non-null    object
# ...

# %%
df_novos_nomes = ['candidato','data_inscricao','nome','genero','estado','idade','formacao','area_atuacao','anos_de_esperiencia','certificaçoes','idiomas','pretensoes_salariais','salario_da_vaga','disponivel_para_viagens','disponivel_para_mudança','é_PCD','status_de_contrataçao']

# %%
df_novos_nomes1 = list(df_candidatos_tecnologia1)

df_novos_nomes1 = ['candidato','data_inscricao','nome','genero','estado','idade','formacao','area_atuacao','anos_de_esperiencia','certificaçoes','idiomas','pretensoes_salariais','salario_da_vaga','disponivel_para_viagens','disponivel_para_mudança','é_PCD','status_de_contrataçao']

df_candidatos_tecnologia1.columns = df_novos_nomes1

df_candidatos_tecnologia1
# Out:
#      candidato data_inscricao            nome     genero estado  idade  \
# 0            1     2022-04-13     Candidato_1  Masculino     SP   23.0
# 1            2     2023-03-12     Candidato_2  Masculino     MG    NaN
# 2            3     2022-09-28     Candidato_3  Masculino     DF   61.0
# 3            4     2022-04-17     Candidato_4      Outro     PE   28.0
# 4            5     2022-03-13     Candidato_5      Outro     RS   19.0
# ..         ...            ...             ...        ...    ...    ...
# 995        996     2023-10-04   Candidato_996  Masculino     MG   60.0
# 996        997     2023-08-19   Candidato_997        NaN     CE   56.0
# 997        998     2022-11-17   Candidato_998        NaN     RS   34.0
# 998        999     2022-11-15   Candidato_999   Feminino     PR   37.0
# 999       1000     2023-09-05  Candidato_1000  Masculino     RJ   41.0
#
#          formacao      area_atuacao  anos_de_esperiencia  certificaçoes  \
# ...

# %%
df_novos_nomes2 = list(df_candidatos_tecnologia2)

df_novos_nomes2 = ['candidato','data_inscricao','nome','genero','estado','idade','formacao','area_atuacao','anos_de_esperiencia','certificaçoes','idiomas','pretensoes_salariais','salario_da_vaga','disponivel_para_viagens','disponivel_para_mudança','é_PCD','status_de_contrataçao']

df_candidatos_tecnologia2.columns = df_novos_nomes2

df_candidatos_tecnologia2
# Out:
#      candidato data_inscricao            nome     genero estado  idade  \
# 0            1     2022-04-13     Candidato_1  Masculino     SP   23.0
# 1            2     2023-03-12     Candidato_2  Masculino     MG    NaN
# 2            3     2022-09-28     Candidato_3  Masculino     DF   61.0
# 3            4     2022-04-17     Candidato_4      Outro     PE   28.0
# 4            5     2022-03-13     Candidato_5      Outro     RS   19.0
# ..         ...            ...             ...        ...    ...    ...
# 995        996     2023-10-04   Candidato_996  Masculino     MG   60.0
# 996        997     2023-08-19   Candidato_997        NaN     CE   56.0
# 997        998     2022-11-17   Candidato_998        NaN     RS   34.0
# 998        999     2022-11-15   Candidato_999   Feminino     PR   37.0
# 999       1000     2023-09-05  Candidato_1000  Masculino     RJ   41.0
#
#          formacao      area_atuacao  anos_de_esperiencia  certificaçoes  \
# ...

# %%
df_novos_nomes3 = list(df_candidatos_tecnologia3)

df_novos_nomes3 = ['candidato','data_inscricao','nome','genero','estado','idade','formacao','area_atuacao','anos_de_esperiencia','certificaçoes','idiomas','pretensoes_salariais','salario_da_vaga','disponivel_para_viagens','disponivel_para_mudança','é_PCD','status_de_contrataçao']

df_candidatos_tecnologia3.columns = df_novos_nomes3

df_candidatos_tecnologia3
# Out:
#      candidato data_inscricao            nome     genero estado  idade  \
# 0            1     2022-04-13     Candidato_1  Masculino     SP   23.0
# 1            2     2023-03-12     Candidato_2  Masculino     MG    NaN
# 2            3     2022-09-28     Candidato_3  Masculino     DF   61.0
# 3            4     2022-04-17     Candidato_4      Outro     PE   28.0
# 4            5     2022-03-13     Candidato_5      Outro     RS   19.0
# ..         ...            ...             ...        ...    ...    ...
# 995        996     2023-10-04   Candidato_996  Masculino     MG   60.0
# 996        997     2023-08-19   Candidato_997        NaN     CE   56.0
# 997        998     2022-11-17   Candidato_998        NaN     RS   34.0
# 998        999     2022-11-15   Candidato_999   Feminino     PR   37.0
# 999       1000     2023-09-05  Candidato_1000  Masculino     RJ   41.0
#
#          formacao      area_atuacao  anos_de_esperiencia  certificaçoes  \
# ...

# %%
df_candidatos_completo = pd.concat([df_candidatos_tecnologia1, df_candidatos_tecnologia2, df_candidatos_tecnologia3], ignore_index=True)
df_candidatos_completo
# Out:
#       candidato data_inscricao            nome     genero estado  idade  \
# 0             1     2022-04-13     Candidato_1  Masculino     SP   23.0
# 1             2     2023-03-12     Candidato_2  Masculino     MG    NaN
# 2             3     2022-09-28     Candidato_3  Masculino     DF   61.0
# 3             4     2022-04-17     Candidato_4      Outro     PE   28.0
# 4             5     2022-03-13     Candidato_5      Outro     RS   19.0
# ...         ...            ...             ...        ...    ...    ...
# 2995        996     2023-10-04   Candidato_996  Masculino     MG   60.0
# 2996        997     2023-08-19   Candidato_997        NaN     CE   56.0
# 2997        998     2022-11-17   Candidato_998        NaN     RS   34.0
# 2998        999     2022-11-15   Candidato_999   Feminino     PR   37.0
# 2999       1000     2023-09-05  Candidato_1000  Masculino     RJ   41.0
#
#           formacao      area_atuacao  anos_de_esperiencia  certificaçoes  \
# ...

# %%
df_candidatos_completo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   candidato                3000 non-null   int64
#  1   data_inscricao           3000 non-null   object
#  2   nome                     2700 non-null   object
#  3   genero                   2700 non-null   object
#  4   estado                   2700 non-null   object
#  5   idade                    2700 non-null   float64
#  6   formacao                 2700 non-null   object
#  7   area_atuacao             2700 non-null   object
#  8   anos_de_esperiencia      2700 non-null   float64
#  9   certificaçoes            2700 non-null   float64
#  10  idiomas                  2700 non-null   object
#  11  pretensoes_salariais     2700 non-null   float64
#  12  salario_da_vaga          2700 non-null   float64
#  13  disponivel_para_viagens  2700 non-null   object
# ...

# %%
df_candidatos_completo.head()
# Out:
#    candidato data_inscricao         nome     genero estado  idade  \
# 0          1     2022-04-13  Candidato_1  Masculino     SP   23.0
# 1          2     2023-03-12  Candidato_2  Masculino     MG    NaN
# 2          3     2022-09-28  Candidato_3  Masculino     DF   61.0
# 3          4     2022-04-17  Candidato_4      Outro     PE   28.0
# 4          5     2022-03-13  Candidato_5      Outro     RS   19.0
#
#        formacao   area_atuacao  anos_de_esperiencia  certificaçoes   idiomas  \
# 0      Mestrado     Financeiro                  4.8            3.0  Espanhol
# 1  Ensino Médio  Administração                  5.5            3.0   Francês
# 2     Doutorado  Administração                  6.3            3.0  Espanhol
# 3           NaN     Engenharia                  2.7            2.0  Espanhol
# 4  Ensino Médio     Tecnologia                  7.4            1.0    Nenhum
#
#    pretensoes_salariais  salario_da_vaga disponivel_para_viagens  \
# ...

# %%
df_candidatos_completo[(df_candidatos_completo['formacao'] == 'Doutorado') & (df_candidatos_completo['area_atuacao'] == 'Tecnologia')]
# Out:
#       candidato data_inscricao           nome     genero estado  idade  \
# 9            10     2023-04-12   Candidato_10      Outro    NaN   38.0
# 81           82     2023-04-01   Candidato_82  Masculino     CE   55.0
# 99          100     2023-06-05  Candidato_100  Masculino     PR   63.0
# 239         240     2023-09-01            NaN  Masculino     DF   34.0
# 298         299     2022-06-02  Candidato_299  Masculino     PE    NaN
# ...         ...            ...            ...        ...    ...    ...
# 2875        876     2022-08-04  Candidato_876   Feminino     RJ   43.0
# 2896        897     2022-09-30  Candidato_897        NaN     MG    NaN
# 2922        923     2023-09-05  Candidato_923      Outro     SP   50.0
# 2951        952     2022-01-06  Candidato_952   Feminino     CE   34.0
# 2986        987     2022-09-16  Candidato_987      Outro     CE   30.0
#
#        formacao area_atuacao  anos_de_esperiencia  certificaçoes   idiomas  \
# ...

# %% [markdown]
# # Analise 01

# %% [markdown]
# Nessa analise vemos na tabela que temos 915 pessoas do genero Masculino, 888 do genero feminino e 897 que nao temos definiçao ate o momento

# %%
genero = pd.DataFrame({'genero': ['Masculino', 'Feminino']})

frequencia_genero = df_candidatos_completo['genero'].value_counts()

plt.bar(frequencia_genero.index, frequencia_genero.values)
plt.show()

print(frequencia_genero)
# Out:
# genero
# Masculino    915
# Outro        897
# Feminino     888
# Name: count, dtype: int64

# %% [markdown]
# # analise 02

# %% [markdown]
# a media salarial das pessoas e de R$6.952,00 reais

# %%
pretensoes = df_candidatos_completo['pretensoes_salariais'].value_counts()

# %%
pretensoes = df_candidatos_completo['pretensoes_salariais'].mean()
print(pretensoes)

indices = df_candidatos_completo.index
salarios = df_candidatos_completo['pretensoes_salariais']

plt.figure(figsize=(16, 14))
plt.scatter(indices, salarios, label='pretensoes')
plt.axhline(y=pretensoes, color='red', linestyle='dashed', label='Média')

plt.title('Pretensões Salariais')
plt.xlabel('Índice')
plt.ylabel('Salário')
plt.legend()
plt.show()
# Out:
# 6952.0

# %% [markdown]
# # Analise 03

# %% [markdown]
# Aqui vemos que na tabela temos 33.9% sao masculinos, 32,9% e feminino e 33,2% e outros

# %%
# Define the mapping for the 'formacao' column
formacao_mapping = {
	'Ensino Médio': 1,
	'Tecnólogo': 2,
	'Graduação': 3,
	'Mestrado': 4,
	'Doutorado': 5
}

porcentagem_genero = df_candidatos_completo['genero'].value_counts(normalize=True) * 100
df_candidatos_completo['porcentagem_genero'] = df_candidatos_completo['genero'].map(porcentagem_genero)
df_candidatos_completo['formacao_numerico'] = df_candidatos_completo['formacao'].map(formacao_mapping)
df_candidatos_completo['porcentagem'] = (df_candidatos_completo['formacao_numerico'] / df_candidatos_completo['formacao_numerico'].sum()) * 100

plt.figure(figsize=(8, 6))
plt.pie(frequencia_genero, labels=frequencia_genero.index, autopct='%1.1f%%')
plt.title('Frequência de Gênero')
plt.show()

print(porcentagem_genero)
# Out:
# genero
# Masculino    33.888889
# Outro        33.222222
# Feminino     32.888889
# Name: proportion, dtype: float64

# %% [markdown]
# # Tabela 04

# %% [markdown]
# Nesta analise temos a informaçsao que a maior quantidade de formados sao do ensino base(ensino medio e tecnologo) e a menor formaçao e doutorado.

# %%
formacao = df_candidatos_completo['formacao'].value_counts()

print(formacao)

plt.figure(figsize=(8, 6))
plt.pie(formacao, labels=formacao.index, autopct='%1.1f%%')
plt.title('Distribuição de Formação')
plt.show()

# vemos que
# Out:
# formacao
# Tecnólogo       582
# Ensino Médio    549
# Graduação       537
# Mestrado        525
# Doutorado       507
# Name: count, dtype: int64

# %% [markdown]
# # Tabela 05

# %% [markdown]
# Na analise vemos que a media por genero esta bem proximo de pretensoes salariais

# %%
media_salario_genero = df_candidatos_completo.groupby('genero')['pretensoes_salariais'].mean().reset_index()

plt.figure(figsize=(8, 6))
plt.bar(media_salario_genero['genero'], media_salario_genero['pretensoes_salariais'], color=['#4CAF50', '#03A9F4', '#FF9800'][:len(media_salario_genero)])
plt.title('Média Salarial por Gênero')
plt.xlabel('Gênero')
plt.ylabel('Média Salarial')
plt.xticks(rotation=45, ha='right')
for i, row in media_salario_genero.iterrows():
    plt.text(i, row['pretensoes_salariais'], f"R${row['pretensoes_salariais']:.2f}", ha='center', va='bottom')
plt.tight_layout()
plt.show()
print(media_salario_genero)
# Out:
#       genero  pretensoes_salariais
# 0   Feminino           6916.603774
# 1  Masculino           6886.690647
# 2      Outro           7010.000000

# %% [markdown]
# # Tabela 06

# %% [markdown]
#  Nessa tabela podemos ver que em medias das pessoas entre 20 e 50 anos estao com um salario nao tao proximos e acima dos 50 anos sao poucas pessoas e com um salario na media entre 6500 e 7200

# %%
agrupado = df_candidatos_completo.groupby('idade')['pretensoes_salariais'].mean()

plt.scatter(agrupado.index, agrupado.values, c=agrupado.index, cmap='viridis')

plt.colorbar(label='idade')
plt.show()

# %% [markdown]
# # Tabela 07

# %% [markdown]
# a tabela mostra que do total de pessoas masculinas com algum tipo de deficiencia sao de 42, femininas sao 48 e outros generos e de 33 pesssoas com deficiencia

# %%
pessoaspcd = df_candidatos_completo.groupby('genero')['é_PCD'].apply(lambda x: (x == 'Sim').sum())
frequencia_genero = df_candidatos_completo['genero'].value_counts()
pessoaspcd = df_candidatos_completo.groupby('genero')['é_PCD'].apply(lambda x: (x == 'Sim').sum()).reindex(frequencia_genero.index, fill_value=0)

plt.figure(figsize=(8, 6))
bar_width = 0.4
x = np.arange(len(frequencia_genero))

plt.bar(x - bar_width/2, frequencia_genero.values, width=bar_width, label='Total por Gênero')
for i, v in enumerate(frequencia_genero.values):
    porcentagem = (v / frequencia_genero.sum()) * 100
    plt.text(i - bar_width/2, v + 5, f"{v} ({porcentagem:.1f}%)", ha='center', size=8)

plt.bar(x + bar_width/2, pessoaspcd.values, width=bar_width, label='PCD por Gênero', color='orange')
for i, v in enumerate(pessoaspcd.values):
    if frequencia_genero.values[i] > 0:
        porcentagem = (v / frequencia_genero.values[i]) * 100
        plt.text(i + bar_width/2, v + 5, f"{v} ({porcentagem:.1f}%)", ha='center', size=8)

plt.xticks(x, frequencia_genero.index, rotation=45)
plt.title('Frequência de Gênero e PCD no Universo de 2700')
plt.xlabel('Gênero')
plt.ylabel('Frequência')
plt.legend()
plt.tight_layout()
plt.show()

print("Frequência de Gênero:")
print(frequencia_genero)
print("\nFrequência de PCD por Gênero:")
print(pessoaspcd)
# Out:
# Frequência de Gênero:
# genero
# Masculino    915
# Outro        897
# Feminino     888
# Name: count, dtype: int64
#
# Frequência de PCD por Gênero:
# genero
# Masculino    48
# Outro        33
# Feminino     42
# Name: é_PCD, dtype: int64

# %%
quantidade_por_estado = df_candidatos_completo['estado'].value_counts()
print(quantidade_por_estado)

plt.figure(figsize=(12, 6))
plt.bar(quantidade_por_estado.index, quantidade_por_estado.values, color=plt.cm.tab20(range(len(quantidade_por_estado))))
plt.title('Quantidade de Pessoas por Estado', fontsize=16)
plt.xlabel('Estado', fontsize=14)
plt.ylabel('Quantidade', fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
for i, v in enumerate(quantidade_por_estado.values):
    plt.text(i, v + 1, f"{v}", ha='center')
plt.show()
# Out:
# estado
# BA    312
# RS    285
# SC    270
# DF    270
# PE    267
# PR    267
# CE    267
# RJ    267
# SP    249
# MG    246
# Name: count, dtype: int64

# %% [markdown]
# # Analise 08

# %% [markdown]
# Essa analise vemos a media de idade das pessoas por estados que a maior media de idade e no RS com uma idade media de 44.4 anos e a menor de 39.6 anos

# %%
media_idade_estado = df_candidatos_completo.groupby('estado')['idade'].mean()

plt.figure(figsize=(12, 6))
plt.plot(media_idade_estado.index, media_idade_estado.values, marker='o', linestyle='-', color='#3498db', linewidth=2)
plt.title('Média de Idade por Estado', fontsize=16)
plt.xlabel('Estado', fontsize=14)
plt.ylabel('Média de Idade', fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()

# Annotate each point with its value
for i, v in enumerate(media_idade_estado.values):
	plt.annotate(f"{v:.1f}", (media_idade_estado.index[i], v), textcoords="offset points", xytext=(0, 5), ha='center')

plt.show()

# %% [markdown]
# # analise 09

# %% [markdown]
# Com os dados da analise anterior, aqui vemos uma media da idade por regiao

# %%
regioes = { 
    'Norte': ['AC', 'AM', 'AP', 'PA', 'RO', 'RR', 'TO'], 
    'Nordeste': ['AL', 'BA', 'CE', 'MA', 'PB', 'PE', 'PI', 'RN', 'SE'], 
    'Sudeste': ['ES', 'MG', 'RJ', 'SP'], 
    'Sul': ['PR', 'RS', 'SC'], 
    'Centro-Oeste': ['DF', 'GO', 'MS', 'MT'] 
}

estado_regiao = {}
for regiao, estados in regioes.items():
    for estado in estados:
        estado_regiao[estado] = regiao

df_candidatos_completo['regiao'] = df_candidatos_completo['estado'].map(estado_regiao)

media_idade_regiao = df_candidatos_completo.groupby('regiao')['idade'].mean()
plt.figure(figsize=(8, 6))
plt.bar(media_idade_regiao.index, media_idade_regiao.values, color=['#4CAF50', '#03A9F4', '#FF9800', '#800080', '#FF69B4'])
plt.title('Média de Idade por Região', fontsize=16)
plt.xlabel('Região', fontsize=14)
plt.ylabel('Média de Idade', fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
for i, v in enumerate(media_idade_regiao.values):
    plt.annotate(f"{v:.1f}", (i, v), textcoords="offset points", xytext=(0, 5), ha='center')
plt.show()
print(media_idade_regiao)
# Out:
# regiao
# Centro-Oeste    40.658228
# Nordeste        41.553435
# Sudeste         41.573333
# Sul             42.662551
# Name: idade, dtype: float64

# %% [markdown]
# # Analise 10

# %% [markdown]
# temos duas tabelas que mostam a quantidade de pessoas na area de atuaçao e o segundo grafico mostra a categoria de cada area que foi dividido em humanas, exatas, ciencias e os Nulos que nao responderam.

# %%
atuacao = df_candidatos_completo['area_atuacao'].value_counts()
humanas = ['Recursos Humanos', 'Educação', 'Administração', 'Marketing']
exatas = ['Tecnologia', 'Engenharia', 'Financeiro']
ciencias = ['Saúde']

def categorizar_area(area):
    if pd.isnull(area):
        return 'Não informado'
    elif area in humanas:
        return 'Humanas'
    elif area in exatas:
        return 'Exatas'
    elif area in ciencias:
        return 'Ciências Biológicas'
    else:
        return 'Outras'

df_candidatos_completo['categoria_area'] = df_candidatos_completo['area_atuacao'].apply(categorizar_area)
atuacao_categoria = df_candidatos_completo['categoria_area'].value_counts()

plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
atuacao = df_candidatos_completo['area_atuacao'].value_counts(dropna=False)
labels = atuacao.index.astype(str)
plt.bar(labels, atuacao.values, color=plt.cm.tab20(range(len(labels))))
for i, v in enumerate(atuacao.values):
    plt.text(i, v + 1, f"{v}", ha='center')
plt.title('Distribuição das Áreas de Atuação', fontsize=16)
plt.xlabel('Área de Atuação', fontsize=14)
plt.ylabel('Quantidade', fontsize=14)
plt.xticks(ticks=range(len(labels)), labels=labels, rotation=45, ha='right')

plt.subplot(1, 2, 2)
plt.bar(atuacao_categoria.index, atuacao_categoria.values, color=['#4CAF50', '#03A9F4', '#FF9800', '#800080', '#FF69B4'][:len(atuacao_categoria)])
for i, v in enumerate(atuacao_categoria.values):
    plt.text(i, v + 1, f"{(v / atuacao_categoria.sum() * 100):.1f}% ({v})", ha='center')
plt.title('Distribuição das Áreas de Atuação por Categoria', fontsize=16)
plt.xlabel('Categoria', fontsize=14)
plt.ylabel('Quantidade', fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Analise 11

# %% [markdown]
# aqui temos uma analise que temos 624 vagas:
# dessas vagas 46,63% o salario e maior que a pretensao dos candidatos;
# 47,60 dessas vagas os candidatos queriam ganhar mais que a vaga oferece;
# 5,77 estao com o salario satisfeito com o que e oferecido

# %%
df_candidatos_completo = df_candidatos_completo.copy()
df_candidatos_completo['diferenca_salarial'] = df_candidatos_completo['salario_da_vaga'] - df_candidatos_completo['pretensoes_salariais']

qnt_vagas = df_candidatos_completo.shape[0]
media_diferenca_salarial = df_candidatos_completo['diferenca_salarial'].mean()
maior_que_pretensao = (df_candidatos_completo['diferenca_salarial'] > 0).sum() / qnt_vagas * 100
menor_que_pretensao = (df_candidatos_completo['diferenca_salarial'] < 0).sum() / qnt_vagas * 100
igual_pretensao = (df_candidatos_completo['diferenca_salarial'] == 0).sum() / qnt_vagas * 100

fig, axs = plt.subplots(1, 1, figsize=(8, 6))
barras = axs.bar(['Maior', 'Menor', 'Igual'], [maior_que_pretensao, menor_que_pretensao, igual_pretensao], color=['#4CAF50', '#FF9800', '#2196F3'])
axs.set_title('Porcentagem de Vagas por Diferença Salarial')
axs.set_xlabel('Diferença Salarial')
axs.set_ylabel('Porcentagem')
for i, v in enumerate([maior_que_pretensao, menor_que_pretensao, igual_pretensao]):
    axs.text(i, v + 1, f"{v:.2f}%", ha='center')
axs.legend(barras, ['Salário maior que a pretensão', 'Salário menor que a pretensão', 'Salário igual à pretensão'], loc='upper right')

plt.tight_layout()
plt.show()

print(f"Quantidade de vagas: {qnt_vagas}")
print(f"Média da diferença salarial: {media_diferenca_salarial:.2f}")
print(f"Porcentagem de vagas com salário maior que a pretensão salarial: {maior_que_pretensao:.2f}%")
print(f"Porcentagem de vagas com salário menor que a pretensão salarial: {menor_que_pretensao:.2f}%")
print(f"Porcentagem de vagas com salário igual à pretensão salarial: {igual_pretensao:.2f}%")
# Out:
# Quantidade de vagas: 624
# Média da diferença salarial: -15.38
# Porcentagem de vagas com salário maior que a pretensão salarial: 46.63%
# Porcentagem de vagas com salário menor que a pretensão salarial: 47.60%
# Porcentagem de vagas com salário igual à pretensão salarial: 5.77%

# %% [markdown]
# # Analise 12

# %% [markdown]
# Nesse grafico vemos que a melhor media salarial vai ser na Area de Engenharia com um valor de R$7293,80 e a menor e ADM com um valor de R$6681,10

# %%
media_salario_area = df_candidatos_completo.groupby('area_atuacao')['salario_da_vaga'].mean()
print(media_salario_area)

area_melhor_paga = media_salario_area.idxmax()
media_melhor_paga = media_salario_area.max()
print(f"A área de atuação com a melhor média salarial é {area_melhor_paga} com uma média de R${media_melhor_paga:.2f}")

plt.figure(figsize=(10,6))
media_salario_area.plot(kind='bar', color=plt.cm.tab20(np.linspace(0, 1, len(media_salario_area))))
plt.title('Média Salarial por Área de Atuação')
plt.xlabel('Área de Atuação')
plt.ylabel('Média Salarial')
plt.xticks(rotation=90)

for i, valor in enumerate(media_salario_area):
    plt.text(i, valor + 100, f"R${valor:.2f}", ha='center')

plt.tight_layout()
plt.show()
# Out:
# area_atuacao
# Administração       6681.132075
# Educação            6960.824742
# Engenharia          7293.617021
# Financeiro          7061.538462
# Marketing           6764.646465
# Recursos Humanos    7016.190476
# Saúde               7162.886598
# Tecnologia          6794.230769
# Name: salario_da_vaga, dtype: float64
# A área de atuação com a melhor média salarial é Engenharia com uma média de R$7293.62

# %% [markdown]
# # Analise 13

# %% [markdown]
# Aqui vemos a media do salario das vagas separadas por generos que a media maior e dos homens seguidos das pessoas que nao se identificaram com nenhum sexo e por ultimo a mylheres

# %%
media_salario_genero = df_candidatos_completo.groupby('genero')['salario_da_vaga'].mean()
print(media_salario_genero)

cores = []
for genero in media_salario_genero.index:
    if genero.lower() == 'feminino':
        cores.append('#FF69B4')  
    elif genero.lower() == 'masculino':
        cores.append('#03A9F4')  
    else:
        cores.append('#800080')  

plt.figure(figsize=(8,6))
media_salario_genero.plot(kind='bar', color=cores)
plt.title('Média Salarial por Gênero')
plt.xlabel('Gênero')
plt.ylabel('Média Salarial')

for i, valor in enumerate(media_salario_genero):
    plt.text(i, valor + 100, f"R${valor:.2f}", ha='center')

plt.tight_layout()
plt.show()
# Out:
# genero
# Feminino     6970.312500
# Masculino    6750.902527
# Outro        6952.592593
# Name: salario_da_vaga, dtype: float64

# %% [markdown]
# # Analise 14

# %%
media_salario_humanas = df_candidatos_completo[df_candidatos_completo['categoria_area'] == 'Humanas']['salario_da_vaga'].mean()
media_salario_exatas = df_candidatos_completo[df_candidatos_completo['categoria_area'] == 'Exatas']['salario_da_vaga'].mean()
media_salario_ciencias = df_candidatos_completo[df_candidatos_completo['categoria_area'] == 'Ciências Biológicas']['salario_da_vaga'].mean()
media_salario_educacao = df_candidatos_completo[df_candidatos_completo['categoria_area'] == 'Educação']['salario_da_vaga'].mean()

print(f"Média salarial em Humanas: R${media_salario_humanas:.2f}")
print(f"Média salarial em Exatas: R${media_salario_exatas:.2f}")
print(f"Média salarial em Ciências Biológicas: R${media_salario_ciencias:.2f}")
print(f"Média salarial em Educação: R${media_salario_educacao:.2f}")

categorias = ['Humanas', 'Exatas', 'Ciências Biológicas', 'Educação']
medias = [media_salario_humanas, media_salario_exatas, media_salario_ciencias, media_salario_educacao]

plt.figure(figsize=(8,8))
plt.pie(medias, labels=categorias, autopct='%1.1f%%', colors=['#4CAF50', '#03A9F4', '#FF9800', '#800080'])
plt.title('Média Salarial por Categoria')
for categoria, media in zip(categorias, medias):
    print(f"{categoria}: R${media:.2f}")

plt.show()
# Out:
# Média salarial em Humanas: R$6821.29
# Média salarial em Exatas: R$7041.72
# Média salarial em Ciências Biológicas: R$7162.89
# Média salarial em Educação: R$6960.82
# Humanas: R$6821.29
# Exatas: R$7041.72
# Ciências Biológicas: R$7162.89
# Educação: R$6960.82
