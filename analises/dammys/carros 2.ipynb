# %% [markdown]
# # Tratando dados sting para ML
#
# Usaremos duas tecnicas para isso.
#
# -dummys
# -one hot enconding

# %%
# %pip install openpyxl -q
# %pip install scikit-learn -q
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

df = pd.read_excel('dados.xlsx')

# %%
df.shape
# Out:
# (986, 7)

# %%
df.head()
# Out:
#          MODELO  KM-LITRO  CILINDROS  PESO(KG)  CAVALOS TRANSMISSAO  \
# 0    LABORGUINI       3.0         12      1200      700  AUTOMATICO
# 1    LABORGUINI       3.0         12      1200      700  AUTOMATICO
# 2    LABORGUINI       3.0         12      1200      700  AUTOMATICO
# 3       FERRARI       3.0         12      1400      640  AUTOMATICO
# 4  ASTON MARTIN       3.5         10      1600      620  AUTOMATICO
#
#          PAIS
# 0      BRASIL
# 1         EUA
# 2     ESPANHA
# 3      CANADA
# 4  INGLATERRA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 986 entries, 0 to 985
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   MODELO       986 non-null    object
#  1   KM-LITRO     984 non-null    float64
#  2   CILINDROS    986 non-null    int64
#  3   PESO(KG)     986 non-null    int64
#  4   CAVALOS      986 non-null    int64
#  5   TRANSMISSAO  986 non-null    object
#  6   PAIS         986 non-null    object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 54.1+ KB

# %%
df['PAIS'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0          BRASIL
# 1             EUA
# 2         ESPANHA
# 3          CANADA
# 4      INGLATERRA
# 5        ALEMANHA
# 6       AUSTRALIA
# 7         NORUEGA
# 8         BELGICA
# 9         HOLANDA
# 10         BRASIL
# 11            EUA
# 12        ESPANHA
# 13         CANADA
# 14     INGLATERRA
# 15       ALEMANHA
# 16      AUSTRALIA
# 17        NORUEGA
# 18        BELGICA
# 19        HOLANDA
# 20         BRASIL
# 21            EUA
# 22        ESPANHA
# 23         CANADA
# 24     INGLATERRA
# 25       ALEMANHA
# 26      AUSTRALIA
# 27        NORUEGA
# 28        BELGICA
# 29        HOLANDA
# 30         BRASIL
# 31            EUA
# 32        ESPANHA
# 33         CANADA
# 34     INGLATERRA
# 35       ALEMANHA
# 36      AUSTRALIA
# 37        NORUEGA
# 38        BELGICA
# 39        HOLANDA
# 40         BRASIL
# 41            EUA
# 42        ESPANHA
# 43         CANADA
# 44     INGLATERRA
# 45       ALEMANHA
# 46      AUSTRALIA
# 47        NORUEGA
# 48        BELGICA
# 49        HOLANDA
# 50         BRASIL
# 51            EUA
# 52        ESPANHA
# 53         CANADA
# 54     INGLATERRA
# 55       ALEMANHA
# 56      AUSTRALIA
# 57        NORUEGA
# 58        BELGICA
# 59        HOLANDA
# 60         BRASIL
# 61            EUA
# 62        ESPANHA
# 63         CANADA
# 64     INGLATERRA
# 65       ALEMANHA
# 66      AUSTRALIA
# 67        NORUEGA
# 68        BELGICA
# 69        HOLANDA
# 70         BRASIL
# 71            EUA
# 72        ESPANHA
# 73         CANADA
# 74     INGLATERRA
# 75       ALEMANHA
# 76      AUSTRALIA
# 77        NORUEGA
# 78        BELGICA
# 79        HOLANDA
# 80         BRASIL
# 81            EUA
# 82        ESPANHA
# 83         CANADA
# 84     INGLATERRA
# 85       ALEMANHA
# 86      AUSTRALIA
# 87        NORUEGA
# 88        BELGICA
# 89        HOLANDA
# 90         BRASIL
# 91            EUA
# 92        ESPANHA
# 93         CANADA
# 94     INGLATERRA
# 95       ALEMANHA
# 96      AUSTRALIA
# 97        NORUEGA
# 98        BELGICA
# 99        HOLANDA
# 100        BRASIL
# 101           EUA
# 102       ESPANHA
# 103        CANADA
# 104    INGLATERRA
# 105      ALEMANHA
# 106     AUSTRALIA
# 107       NORUEGA
# 108       BELGICA
# 109       HOLANDA
# 110        BRASIL
# 111           EUA
# 112       ESPANHA
# 113        CANADA
# 114    INGLATERRA
# 115      ALEMANHA
# 116     AUSTRALIA
# 117       NORUEGA
# 118       BELGICA
# 119       HOLANDA
# 120        BRASIL
# 121           EUA
# 122       ESPANHA
# 123        CANADA
# 124    INGLATERRA
# 125      ALEMANHA
# 126     AUSTRALIA
# 127       NORUEGA
# 128       BELGICA
# 129       HOLANDA
# 130        BRASIL
# 131           EUA
# 132       ESPANHA
# 133        CANADA
# 134    INGLATERRA
# 135      ALEMANHA
# 136     AUSTRALIA
# 137       NORUEGA
# 138       BELGICA
# 139       HOLANDA
# 140        BRASIL
# 141           EUA
# 142       ESPANHA
# 143        CANADA
# 144    INGLATERRA
# 145      ALEMANHA
# 146     AUSTRALIA
# 147       NORUEGA
# 148       BELGICA
# 149       HOLANDA
# 150        BRASIL
# 151           EUA
# 152       ESPANHA
# 153        CANADA
# 154    INGLATERRA
# 155      ALEMANHA
# 156     AUSTRALIA
# 157       NORUEGA
# 158       BELGICA
# 159       HOLANDA
# 160        BRASIL
# 161           EUA
# 162       ESPANHA
# 163        CANADA
# 164    INGLATERRA
# 165      ALEMANHA
# 166     AUSTRALIA
# 167       NORUEGA
# 168       BELGICA
# 169       HOLANDA
# 170        BRASIL
# 171           EUA
# 172       ESPANHA
# 173        CANADA
# 174    INGLATERRA
# 175      ALEMANHA
# 176     AUSTRALIA
# 177       NORUEGA
# 178       BELGICA
# 179       HOLANDA
# 180        BRASIL
# 181           EUA
# 182       ESPANHA
# 183        CANADA
# 184    INGLATERRA
# 185      ALEMANHA
# 186     AUSTRALIA
# 187       NORUEGA
# 188       BELGICA
# 189       HOLANDA
# 190        BRASIL
# 191           EUA
# 192       ESPANHA
# 193        CANADA
# 194    INGLATERRA
# 195      ALEMANHA
# 196     AUSTRALIA
# 197       NORUEGA
# 198       BELGICA
# 199       HOLANDA
# 200        BRASIL
# 201           EUA
# 202       ESPANHA
# 203        CANADA
# 204    INGLATERRA
# 205      ALEMANHA
# 206     AUSTRALIA
# 207       NORUEGA
# 208       BELGICA
# 209       HOLANDA
# 210        BRASIL
# 211           EUA
# 212       ESPANHA
# 213        CANADA
# 214    INGLATERRA
# 215      ALEMANHA
# 216     AUSTRALIA
# 217       NORUEGA
# 218       BELGICA
# 219       HOLANDA
# 220        BRASIL
# 221           EUA
# 222       ESPANHA
# 223        CANADA
# 224    INGLATERRA
# 225      ALEMANHA
# 226     AUSTRALIA
# 227       NORUEGA
# 228       BELGICA
# 229       HOLANDA
# 230        BRASIL
# 231           EUA
# 232       ESPANHA
# 233        CANADA
# 234    INGLATERRA
# 235      ALEMANHA
# 236     AUSTRALIA
# 237       NORUEGA
# 238       BELGICA
# 239       HOLANDA
# 240        BRASIL
# 241           EUA
# 242       ESPANHA
# 243        CANADA
# 244    INGLATERRA
# 245      ALEMANHA
# 246     AUSTRALIA
# 247       NORUEGA
# 248       BELGICA
# 249       HOLANDA
# 250        BRASIL
# 251           EUA
# 252       ESPANHA
# 253        CANADA
# 254    INGLATERRA
# 255      ALEMANHA
# 256     AUSTRALIA
# 257       NORUEGA
# 258       BELGICA
# 259       HOLANDA
# 260        BRASIL
# 261           EUA
# 262       ESPANHA
# 263        CANADA
# 264    INGLATERRA
# 265      ALEMANHA
# 266     AUSTRALIA
# 267       NORUEGA
# 268       BELGICA
# 269       HOLANDA
# 270        BRASIL
# 271           EUA
# 272       ESPANHA
# 273        CANADA
# 274    INGLATERRA
# 275      ALEMANHA
# 276     AUSTRALIA
# 277       NORUEGA
# 278       BELGICA
# 279       HOLANDA
# 280        BRASIL
# 281           EUA
# 282       ESPANHA
# 283        CANADA
# 284    INGLATERRA
# 285      ALEMANHA
# 286     AUSTRALIA
# 287       NORUEGA
# 288       BELGICA
# 289       HOLANDA
# 290        BRASIL
# 291           EUA
# 292       ESPANHA
# 293        CANADA
# 294    INGLATERRA
# 295      ALEMANHA
# 296     AUSTRALIA
# 297       NORUEGA
# 298       BELGICA
# 299       HOLANDA
# 300        BRASIL
# 301           EUA
# 302       ESPANHA
# 303        CANADA
# 304    INGLATERRA
# 305      ALEMANHA
# 306     AUSTRALIA
# 307       NORUEGA
# 308       BELGICA
# 309       HOLANDA
# 310        BRASIL
# 311           EUA
# 312       ESPANHA
# 313        CANADA
# 314    INGLATERRA
# 315      ALEMANHA
# 316     AUSTRALIA
# 317       NORUEGA
# 318       BELGICA
# 319       HOLANDA
# 320        BRASIL
# 321           EUA
# 322       ESPANHA
# 323        CANADA
# 324    INGLATERRA
# 325      ALEMANHA
# 326     AUSTRALIA
# 327       NORUEGA
# 328       BELGICA
# 329       HOLANDA
# 330        BRASIL
# 331           EUA
# 332       ESPANHA
# 333        CANADA
# 334    INGLATERRA
# 335      ALEMANHA
# 336     AUSTRALIA
# 337       NORUEGA
# 338       BELGICA
# 339       HOLANDA
# 340        BRASIL
# 341           EUA
# 342       ESPANHA
# 343        CANADA
# 344    INGLATERRA
# 345      ALEMANHA
# 346     AUSTRALIA
# 347       NORUEGA
# 348       BELGICA
# 349       HOLANDA
# 350        BRASIL
# 351           EUA
# 352       ESPANHA
# 353        CANADA
# 354    INGLATERRA
# 355      ALEMANHA
# 356     AUSTRALIA
# 357       NORUEGA
# 358       BELGICA
# 359       HOLANDA
# 360        BRASIL
# 361           EUA
# 362       ESPANHA
# 363        CANADA
# 364    INGLATERRA
# 365      ALEMANHA
# 366     AUSTRALIA
# 367       NORUEGA
# 368       BELGICA
# 369       HOLANDA
# 370        BRASIL
# 371           EUA
# 372       ESPANHA
# 373        CANADA
# 374    INGLATERRA
# 375      ALEMANHA
# 376     AUSTRALIA
# 377       NORUEGA
# 378       BELGICA
# 379       HOLANDA
# 380        BRASIL
# 381           EUA
# 382       ESPANHA
# 383        CANADA
# 384    INGLATERRA
# 385      ALEMANHA
# 386     AUSTRALIA
# 387       NORUEGA
# 388       BELGICA
# 389       HOLANDA
# 390        BRASIL
# 391           EUA
# 392       ESPANHA
# 393        CANADA
# 394    INGLATERRA
# 395      ALEMANHA
# 396     AUSTRALIA
# 397       NORUEGA
# 398       BELGICA
# 399       HOLANDA
# 400        BRASIL
# 401           EUA
# 402       ESPANHA
# 403        CANADA
# 404    INGLATERRA
# 405      ALEMANHA
# 406     AUSTRALIA
# 407       NORUEGA
# 408       BELGICA
# 409       HOLANDA
# 410        BRASIL
# 411           EUA
# 412       ESPANHA
# 413        CANADA
# 414    INGLATERRA
# 415      ALEMANHA
# 416     AUSTRALIA
# 417       NORUEGA
# 418       BELGICA
# 419       HOLANDA
# 420        BRASIL
# 421           EUA
# 422       ESPANHA
# 423        CANADA
# 424    INGLATERRA
# 425      ALEMANHA
# 426     AUSTRALIA
# 427       NORUEGA
# 428       BELGICA
# 429       HOLANDA
# 430        BRASIL
# 431           EUA
# 432       ESPANHA
# 433        CANADA
# 434    INGLATERRA
# 435      ALEMANHA
# 436     AUSTRALIA
# 437       NORUEGA
# 438       BELGICA
# 439       HOLANDA
# 440        BRASIL
# 441           EUA
# 442       ESPANHA
# 443        CANADA
# 444    INGLATERRA
# 445      ALEMANHA
# 446     AUSTRALIA
# 447       NORUEGA
# 448       BELGICA
# 449       HOLANDA
# 450        BRASIL
# 451           EUA
# 452       ESPANHA
# 453        CANADA
# 454    INGLATERRA
# 455      ALEMANHA
# 456     AUSTRALIA
# 457       NORUEGA
# 458       BELGICA
# 459       HOLANDA
# 460        BRASIL
# 461           EUA
# 462       ESPANHA
# 463        CANADA
# 464    INGLATERRA
# 465      ALEMANHA
# 466     AUSTRALIA
# 467       NORUEGA
# 468       BELGICA
# 469       HOLANDA
# 470        BRASIL
# 471           EUA
# 472       ESPANHA
# 473        CANADA
# 474    INGLATERRA
# 475      ALEMANHA
# 476     AUSTRALIA
# 477       NORUEGA
# 478       BELGICA
# 479       HOLANDA
# 480        BRASIL
# 481           EUA
# 482       ESPANHA
# 483        CANADA
# 484    INGLATERRA
# 485      ALEMANHA
# 486     AUSTRALIA
# 487       NORUEGA
# 488       BELGICA
# 489       HOLANDA
# 490        BRASIL
# 491           EUA
# 492       ESPANHA
# 493        CANADA
# 494    INGLATERRA
# 495      ALEMANHA
# 496     AUSTRALIA
# 497       NORUEGA
# 498       BELGICA
# 499       HOLANDA
# 500        BRASIL
# 501           EUA
# 502       ESPANHA
# 503        CANADA
# 504    INGLATERRA
# 505      ALEMANHA
# 506     AUSTRALIA
# 507       NORUEGA
# 508       BELGICA
# 509       HOLANDA
# 510        BRASIL
# 511           EUA
# 512       ESPANHA
# 513        CANADA
# 514    INGLATERRA
# 515      ALEMANHA
# 516     AUSTRALIA
# 517       NORUEGA
# 518       BELGICA
# 519       HOLANDA
# 520        BRASIL
# 521           EUA
# 522       ESPANHA
# 523        CANADA
# 524    INGLATERRA
# 525      ALEMANHA
# 526     AUSTRALIA
# 527       NORUEGA
# 528       BELGICA
# 529       HOLANDA
# 530        BRASIL
# 531           EUA
# 532       ESPANHA
# 533        CANADA
# 534    INGLATERRA
# 535      ALEMANHA
# 536     AUSTRALIA
# 537       NORUEGA
# 538       BELGICA
# 539       HOLANDA
# 540        BRASIL
# 541           EUA
# 542       ESPANHA
# 543        CANADA
# 544    INGLATERRA
# 545      ALEMANHA
# 546     AUSTRALIA
# 547       NORUEGA
# 548       BELGICA
# 549       HOLANDA
# 550        BRASIL
# 551           EUA
# 552       ESPANHA
# 553        CANADA
# 554    INGLATERRA
# 555      ALEMANHA
# 556     AUSTRALIA
# 557       NORUEGA
# 558       BELGICA
# 559       HOLANDA
# 560        BRASIL
# 561           EUA
# 562       ESPANHA
# 563        CANADA
# 564    INGLATERRA
# 565      ALEMANHA
# 566     AUSTRALIA
# 567       NORUEGA
# 568       BELGICA
# 569       HOLANDA
# 570        BRASIL
# 571           EUA
# 572       ESPANHA
# 573        CANADA
# 574    INGLATERRA
# 575      ALEMANHA
# 576     AUSTRALIA
# 577       NORUEGA
# 578       BELGICA
# 579       HOLANDA
# 580        BRASIL
# 581           EUA
# 582       ESPANHA
# 583        CANADA
# 584    INGLATERRA
# 585      ALEMANHA
# 586     AUSTRALIA
# 587       NORUEGA
# 588       BELGICA
# 589       HOLANDA
# 590        BRASIL
# 591           EUA
# 592       ESPANHA
# 593        CANADA
# 594    INGLATERRA
# 595      ALEMANHA
# 596     AUSTRALIA
# 597       NORUEGA
# 598       BELGICA
# 599       HOLANDA
# 600        BRASIL
# 601           EUA
# 602       ESPANHA
# 603        CANADA
# 604    INGLATERRA
# 605      ALEMANHA
# 606     AUSTRALIA
# 607       NORUEGA
# 608       BELGICA
# 609       HOLANDA
# 610        BRASIL
# 611           EUA
# 612       ESPANHA
# 613        CANADA
# 614    INGLATERRA
# 615      ALEMANHA
# 616     AUSTRALIA
# 617       NORUEGA
# 618       BELGICA
# 619       HOLANDA
# 620        BRASIL
# 621           EUA
# 622       ESPANHA
# 623        CANADA
# 624    INGLATERRA
# 625      ALEMANHA
# 626     AUSTRALIA
# 627       NORUEGA
# 628       BELGICA
# 629       HOLANDA
# 630        BRASIL
# 631           EUA
# 632       ESPANHA
# 633        CANADA
# 634    INGLATERRA
# 635      ALEMANHA
# 636     AUSTRALIA
# 637       NORUEGA
# 638       BELGICA
# 639       HOLANDA
# 640        BRASIL
# 641           EUA
# 642       ESPANHA
# 643        CANADA
# 644    INGLATERRA
# 645      ALEMANHA
# 646     AUSTRALIA
# 647       NORUEGA
# 648       BELGICA
# 649       HOLANDA
# 650        BRASIL
# 651           EUA
# 652       ESPANHA
# 653        CANADA
# 654    INGLATERRA
# 655      ALEMANHA
# 656     AUSTRALIA
# 657       NORUEGA
# 658       BELGICA
# 659       HOLANDA
# 660        BRASIL
# 661           EUA
# 662       ESPANHA
# 663        CANADA
# 664    INGLATERRA
# 665      ALEMANHA
# 666     AUSTRALIA
# 667       NORUEGA
# 668       BELGICA
# 669       HOLANDA
# 670        BRASIL
# 671           EUA
# 672       ESPANHA
# 673        CANADA
# 674    INGLATERRA
# 675      ALEMANHA
# 676     AUSTRALIA
# 677       NORUEGA
# 678       BELGICA
# 679       HOLANDA
# 680        BRASIL
# 681           EUA
# 682       ESPANHA
# 683        CANADA
# 684    INGLATERRA
# 685      ALEMANHA
# 686     AUSTRALIA
# 687       NORUEGA
# 688       BELGICA
# 689       HOLANDA
# 690        BRASIL
# 691           EUA
# 692       ESPANHA
# 693        CANADA
# 694    INGLATERRA
# 695      ALEMANHA
# 696     AUSTRALIA
# 697       NORUEGA
# 698       BELGICA
# 699       HOLANDA
# 700        BRASIL
# 701           EUA
# 702       ESPANHA
# 703        CANADA
# 704    INGLATERRA
# 705      ALEMANHA
# 706     AUSTRALIA
# 707       NORUEGA
# 708       BELGICA
# 709       HOLANDA
# 710        BRASIL
# 711           EUA
# 712       ESPANHA
# 713        CANADA
# 714    INGLATERRA
# 715      ALEMANHA
# 716     AUSTRALIA
# 717       NORUEGA
# 718       BELGICA
# 719       HOLANDA
# 720        BRASIL
# 721           EUA
# 722       ESPANHA
# 723        CANADA
# 724    INGLATERRA
# 725      ALEMANHA
# 726     AUSTRALIA
# 727       NORUEGA
# 728       BELGICA
# 729       HOLANDA
# 730        BRASIL
# 731           EUA
# 732       ESPANHA
# 733        CANADA
# 734    INGLATERRA
# 735      ALEMANHA
# 736     AUSTRALIA
# 737       NORUEGA
# 738       BELGICA
# 739       HOLANDA
# 740        BRASIL
# 741           EUA
# 742       ESPANHA
# 743        CANADA
# 744    INGLATERRA
# 745      ALEMANHA
# 746     AUSTRALIA
# 747       NORUEGA
# 748       BELGICA
# 749       HOLANDA
# 750        BRASIL
# 751           EUA
# 752       ESPANHA
# 753        CANADA
# 754    INGLATERRA
# 755      ALEMANHA
# 756     AUSTRALIA
# 757       NORUEGA
# 758       BELGICA
# 759       HOLANDA
# 760        BRASIL
# 761           EUA
# 762       ESPANHA
# 763        CANADA
# 764    INGLATERRA
# 765      ALEMANHA
# 766     AUSTRALIA
# 767       NORUEGA
# 768       BELGICA
# 769       HOLANDA
# 770        BRASIL
# 771           EUA
# 772       ESPANHA
# 773        CANADA
# 774    INGLATERRA
# 775      ALEMANHA
# 776     AUSTRALIA
# 777       NORUEGA
# 778       BELGICA
# 779       HOLANDA
# 780        BRASIL
# 781           EUA
# 782       ESPANHA
# 783        CANADA
# 784    INGLATERRA
# 785      ALEMANHA
# 786     AUSTRALIA
# 787       NORUEGA
# 788       BELGICA
# 789       HOLANDA
# 790        BRASIL
# 791           EUA
# 792       ESPANHA
# 793        CANADA
# 794    INGLATERRA
# 795      ALEMANHA
# 796     AUSTRALIA
# 797       NORUEGA
# 798       BELGICA
# 799       HOLANDA
# 800        BRASIL
# 801           EUA
# 802       ESPANHA
# 803        CANADA
# 804    INGLATERRA
# 805      ALEMANHA
# 806     AUSTRALIA
# 807       NORUEGA
# 808       BELGICA
# 809       HOLANDA
# 810        BRASIL
# 811           EUA
# 812       ESPANHA
# 813        CANADA
# 814    INGLATERRA
# 815      ALEMANHA
# 816     AUSTRALIA
# 817       NORUEGA
# 818       BELGICA
# 819       HOLANDA
# 820        BRASIL
# 821           EUA
# 822       ESPANHA
# 823        CANADA
# 824    INGLATERRA
# 825      ALEMANHA
# 826     AUSTRALIA
# 827       NORUEGA
# 828       BELGICA
# 829       HOLANDA
# 830        BRASIL
# 831           EUA
# 832       ESPANHA
# 833        CANADA
# 834    INGLATERRA
# 835      ALEMANHA
# 836     AUSTRALIA
# 837       NORUEGA
# 838       BELGICA
# 839       HOLANDA
# 840        BRASIL
# 841           EUA
# 842       ESPANHA
# 843        CANADA
# 844    INGLATERRA
# 845      ALEMANHA
# 846     AUSTRALIA
# 847       NORUEGA
# 848       BELGICA
# 849       HOLANDA
# 850        BRASIL
# 851           EUA
# 852       ESPANHA
# 853        CANADA
# 854    INGLATERRA
# 855      ALEMANHA
# 856     AUSTRALIA
# 857       NORUEGA
# 858       BELGICA
# 859       HOLANDA
# 860        BRASIL
# 861           EUA
# 862       ESPANHA
# 863        CANADA
# 864    INGLATERRA
# 865      ALEMANHA
# 866     AUSTRALIA
# 867       NORUEGA
# 868       BELGICA
# 869       HOLANDA
# 870        BRASIL
# 871           EUA
# 872       ESPANHA
# 873        CANADA
# 874    INGLATERRA
# 875      ALEMANHA
# 876     AUSTRALIA
# 877       NORUEGA
# 878       BELGICA
# 879       HOLANDA
# 880        BRASIL
# 881           EUA
# 882       ESPANHA
# 883        CANADA
# 884    INGLATERRA
# 885      ALEMANHA
# 886     AUSTRALIA
# 887       NORUEGA
# 888       BELGICA
# 889       HOLANDA
# 890        BRASIL
# 891           EUA
# 892       ESPANHA
# 893        CANADA
# 894    INGLATERRA
# 895      ALEMANHA
# 896     AUSTRALIA
# 897       NORUEGA
# 898       BELGICA
# 899       HOLANDA
# 900        BRASIL
# 901           EUA
# 902       ESPANHA
# 903        CANADA
# 904    INGLATERRA
# 905      ALEMANHA
# 906     AUSTRALIA
# 907       NORUEGA
# 908       BELGICA
# 909       HOLANDA
# 910        BRASIL
# 911           EUA
# 912       ESPANHA
# 913        CANADA
# 914    INGLATERRA
# 915      ALEMANHA
# 916     AUSTRALIA
# 917       NORUEGA
# 918       BELGICA
# 919       HOLANDA
# 920        BRASIL
# 921           EUA
# 922       ESPANHA
# 923        CANADA
# 924    INGLATERRA
# 925      ALEMANHA
# 926     AUSTRALIA
# 927       NORUEGA
# 928       BELGICA
# 929       HOLANDA
# 930        BRASIL
# 931           EUA
# 932       ESPANHA
# 933        CANADA
# 934    INGLATERRA
# 935      ALEMANHA
# 936     AUSTRALIA
# 937       NORUEGA
# 938       BELGICA
# 939       HOLANDA
# 940        BRASIL
# 941           EUA
# 942       ESPANHA
# 943        CANADA
# 944    INGLATERRA
# 945      ALEMANHA
# 946     AUSTRALIA
# 947       NORUEGA
# 948       BELGICA
# 949       HOLANDA
# 950        BRASIL
# 951           EUA
# 952       ESPANHA
# 953        CANADA
# 954    INGLATERRA
# 955      ALEMANHA
# 956     AUSTRALIA
# 957       NORUEGA
# 958       BELGICA
# 959       HOLANDA
# 960        BRASIL
# 961           EUA
# 962       ESPANHA
# 963        CANADA
# 964    INGLATERRA
# 965      ALEMANHA
# 966     AUSTRALIA
# 967       NORUEGA
# 968       BELGICA
# 969       HOLANDA
# 970        BRASIL
# 971           EUA
# 972       ESPANHA
# 973        CANADA
# 974    INGLATERRA
# 975      ALEMANHA
# 976     AUSTRALIA
# 977       NORUEGA
# 978       BELGICA
# 979       HOLANDA
# 980        BRASIL
# 981           EUA
# 982       ESPANHA
# 983        CANADA
# 984    INGLATERRA
# 985      ALEMANHA
# Name: PAIS, dtype: object>

# %%
df.groupby('TRANSMISSAO').size()
# Out:
# TRANSMISSAO
# AUTOMATICO    536
# MANUAL        450
# dtype: int64

# %%
df['TRANSMISSAO'].value_counts()
# Out:
# TRANSMISSAO
# AUTOMATICO    536
# MANUAL        450
# Name: count, dtype: int64

# %%
df['MODELO'].value_counts()
# Out:
# MODELO
# MERCEDES SL80    66
# ASTON MARTIN     66
# HONDA FIT        66
# PALIO            66
# MOBI             66
# UNO              66
# PASSAT           66
# FERRARI          54
# LABORGUINI       50
# CORSA            42
# SAVEIRO          42
# BMW X5           36
# JEEP COMPASS     36
# CRETA            36
# PAJERO           36
# COROLLA          36
# HB20             30
# BMW X1           30
# JEEP RENEGADE    24
# PARATI           24
# GOL              24
# VECTRA           24
# Name: count, dtype: int64

# %% [markdown]
# # Metodo One hot Encoding

# %% [markdown]
# usaremos o scikit-learn para esta tecnica

# %% [markdown]
# !pip install scikit-leam -q

# %%
df =pd.read_excel('./dados.xlsx')
df.shape
# Out:
# (986, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 986 entries, 0 to 985
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   MODELO       986 non-null    object
#  1   KM-LITRO     984 non-null    float64
#  2   CILINDROS    986 non-null    int64
#  3   PESO(KG)     986 non-null    int64
#  4   CAVALOS      986 non-null    int64
#  5   TRANSMISSAO  986 non-null    object
#  6   PAIS         986 non-null    object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 54.1+ KB

# %%
df.head()
# Out:
#          MODELO  KM-LITRO  CILINDROS  PESO(KG)  CAVALOS TRANSMISSAO  \
# 0    LABORGUINI       3.0         12      1200      700  AUTOMATICO
# 1    LABORGUINI       3.0         12      1200      700  AUTOMATICO
# 2    LABORGUINI       3.0         12      1200      700  AUTOMATICO
# 3       FERRARI       3.0         12      1400      640  AUTOMATICO
# 4  ASTON MARTIN       3.5         10      1600      620  AUTOMATICO
#
#          PAIS
# 0      BRASIL
# 1         EUA
# 2     ESPANHA
# 3      CANADA
# 4  INGLATERRA

# %%
from sklearn.preprocessing import LabelEncoder # type: ignore

# %%
lb = LabelEncoder()

for serie in ['PAIS', 'TRANSMISSAO', 'MODELO']:
    df[serie] = lb.fit_transform(df[serie])

# %%
df.shape
# Out:
# (986, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 986 entries, 0 to 985
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   MODELO       986 non-null    int64
#  1   KM-LITRO     984 non-null    float64
#  2   CILINDROS    986 non-null    int64
#  3   PESO(KG)     986 non-null    int64
#  4   CAVALOS      986 non-null    int64
#  5   TRANSMISSAO  986 non-null    int64
#  6   PAIS         986 non-null    int64
# dtypes: float64(1), int64(6)
# memory usage: 54.1 KB

# %%
df.head()
# Out:
#    MODELO  KM-LITRO  CILINDROS  PESO(KG)  CAVALOS  TRANSMISSAO  PAIS
# 0      12       3.0         12      1200      700            0     3
# 1      12       3.0         12      1200      700            0     6
# 2      12       3.0         12      1200      700            0     5
# 3       6       3.0         12      1400      640            0     4
# 4       0       3.5         10      1600      620            0     8

# %%
df['PAIS'].value_counts()
# Out:
# PAIS
# 3    99
# 6    99
# 5    99
# 4    99
# 8    99
# 0    99
# 1    98
# 9    98
# 2    98
# 7    98
# Name: count, dtype: int64

# %%
df.groupby('PAIS').size()
# Out:
# PAIS
# 0    99
# 1    98
# 2    98
# 3    99
# 4    99
# 5    99
# 6    99
# 7    98
# 8    99
# 9    98
# dtype: int64

# %%
df_dados = pd.read_excel('dados.xlsx')

legendas = {}

for var in ['PAIS', 'TRANSMISSAO', 'MODELO']:
    lb = LabelEncoder()  

    df_originais = df_dados[var].copy()

    # Fit and transform the data
    df_dados[var] = lb.fit_transform(df_originais)

    # Create a legend mapping
    legenda_var = dict(zip(lb.classes_, lb.transform(lb.classes_)))
    legendas[var] = legenda_var

# Print the legends
for var, mapa in legendas.items():
    print(f"\nLegenda para {var}:")
    for k, v in mapa.items():
        print(f" {k} : {v}")
# Out:
# Legenda para PAIS:
#  ALEMANHA : 0
#  AUSTRALIA : 1
#  BELGICA : 2
#  BRASIL : 3
#  CANADA : 4
#  ESPANHA : 5
#  EUA : 6
#  HOLANDA : 7
#  INGLATERRA : 8
#  NORUEGA : 9
#
# Legenda para TRANSMISSAO:
#  AUTOMATICO : 0
#  MANUAL : 1
#
# Legenda para MODELO:
#  ASTON MARTIN : 0
#  BMW X1 : 1
#  BMW X5 : 2
#  COROLLA : 3
#  CORSA : 4
#  CRETA : 5
#  FERRARI : 6
#  GOL : 7
#  HB20 : 8
#  HONDA FIT : 9
#  JEEP COMPASS : 10
#  JEEP RENEGADE : 11
#  LABORGUINI : 12
#  MERCEDES SL80 : 13
#  MOBI : 14
#  PAJERO : 15
#  PALIO : 16
#  PARATI : 17
#  PASSAT : 18
#  SAVEIRO : 19
#  UNO : 20
#  VECTRA : 21

# %%
df_dados.describe()
# Out:
#            MODELO    KM-LITRO   CILINDROS     PESO(KG)      CAVALOS  \
# count  986.000000  984.000000  986.000000   986.000000   986.000000
# mean    10.855984    8.209553    6.115619  1959.432049   262.622718
# std      6.333342    3.718411    2.764683   459.769620   209.544669
# min      0.000000    3.000000    3.000000  1200.000000   116.000000
# 25%      6.000000    4.500000    4.000000  1700.000000   118.000000
# 50%     12.000000    8.000000    4.000000  1700.000000   118.000000
# 75%     16.000000   11.000000    8.000000  2300.000000   340.000000
# max     21.000000   14.000000   12.000000  3000.000000  1800.000000
#
#        TRANSMISSAO        PAIS
# count   986.000000  986.000000
# mean      0.456389    4.498986
# std       0.498347    2.871618
# min       0.000000    0.000000
# 25%       0.000000    2.000000
# 50%       0.000000    4.500000
# 75%       1.000000    7.000000
# max       1.000000    9.000000

# %%
# %pip install seaborn -q

from sklearn.preprocessing import MinMaxScaler, StandardScaler # type: ignore
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
plt.Figure(figsize=(10, 5))
ax =sns.boxplot(data=df_dados)

# %%
padronizar = StandardScaler().fit(df_dados)

df_padronizado = padronizar.transform(df_dados)

df_padronizado
# Out:
# array([[ 0.18072557, -1.40172823,  2.12949108, ...,  2.08833394,
#         -0.91627083, -0.52226527],
#        [ 0.18072557, -1.40172823,  2.12949108, ...,  2.08833394,
#         -0.91627083,  0.52297199],
#        [ 0.18072557, -1.40172823,  2.12949108, ...,  2.08833394,
#         -0.91627083,  0.17455957],
#        ...,
#        [ 1.44452282,  1.42349437, -0.76561848, ..., -0.69052633,
#          1.09138037, -0.17385285],
#        [ 0.49667488,  1.55802878, -0.76561848, ..., -0.69052633,
#          1.09138037,  1.21979682],
#        [ 1.1285735 , -0.05638414, -0.04184109, ..., -0.69052633,
#          1.09138037, -1.56750252]], shape=(986, 7))

# %%
df_padronizado = pd.DataFrame(df_padronizado)

df_padronizado.columns = df_dados.columns

df_padronizado.describe()
# Out:
#              MODELO      KM-LITRO     CILINDROS      PESO(KG)       CAVALOS  \
# count  9.860000e+02  9.840000e+02  9.860000e+02  9.860000e+02  9.860000e+02
# mean   1.171026e-17 -3.402879e-16 -1.981737e-17  2.071816e-17  9.908684e-17
# std    1.000507e+00  1.000509e+00  1.000507e+00  1.000507e+00  1.000507e+00
# min   -1.714970e+00 -1.401728e+00 -1.127507e+00 -1.652605e+00 -7.000757e-01
# 25%   -7.671224e-01 -9.981250e-01 -7.656185e-01 -5.645517e-01 -6.905263e-01
# 50%    1.807256e-01 -5.638414e-02 -7.656185e-01 -5.645517e-01 -6.905263e-01
# 75%    8.126242e-01  7.508223e-01  6.819363e-01  7.411120e-01  3.694513e-01
# max    1.602497e+00  1.558029e+00  2.129491e+00  2.264386e+00  7.340475e+00
#
#         TRANSMISSAO          PAIS
# count  9.860000e+02  9.860000e+02
# mean  -6.305526e-17 -1.076443e-16
# std    1.000507e+00  1.000507e+00
# min   -9.162708e-01 -1.567503e+00
# 25%   -9.162708e-01 -8.706777e-01
# 50%   -9.162708e-01  3.533594e-04
# 75%    1.091380e+00  8.713844e-01
# max    1.091380e+00  1.568209e+00

# %%
plt.Figure(figsize=(10, 5))
ax =sns.boxplot(data=df_padronizado)

# %%
normalizar =MinMaxScaler().fit(df_dados)

df_normalizado = normalizar.transform(df_dados)

# %%
df_normalizado
# Out:
# array([[0.57142857, 0.        , 1.        , ..., 0.34679335, 0.        ,
#         0.33333333],
#        [0.57142857, 0.        , 1.        , ..., 0.34679335, 0.        ,
#         0.66666667],
#        [0.57142857, 0.        , 1.        , ..., 0.34679335, 0.        ,
#         0.55555556],
#        ...,
#        [0.95238095, 0.95454545, 0.11111111, ..., 0.00118765, 1.        ,
#         0.44444444],
#        [0.66666667, 1.        , 0.11111111, ..., 0.00118765, 1.        ,
#         0.88888889],
#        [0.85714286, 0.45454545, 0.33333333, ..., 0.00118765, 1.        ,
#         0.        ]], shape=(986, 7))

# %%
df_normalizado = pd.DataFrame(df_normalizado, columns=df_dados.columns)

# %%
df_normalizado.head()
# Out:
#      MODELO  KM-LITRO  CILINDROS  PESO(KG)   CAVALOS  TRANSMISSAO      PAIS
# 0  0.571429  0.000000   1.000000  0.000000  0.346793          0.0  0.333333
# 1  0.571429  0.000000   1.000000  0.000000  0.346793          0.0  0.666667
# 2  0.571429  0.000000   1.000000  0.000000  0.346793          0.0  0.555556
# 3  0.285714  0.000000   1.000000  0.111111  0.311164          0.0  0.444444
# 4  0.000000  0.045455   0.777778  0.222222  0.299287          0.0  0.888889

# %%
df_normalizado.describe()
# Out:
#            MODELO    KM-LITRO   CILINDROS    PESO(KG)     CAVALOS  \
# count  986.000000  984.000000  986.000000  986.000000  986.000000
# mean     0.516952    0.473596    0.346180    0.421907    0.087068
# std      0.301588    0.338037    0.307187    0.255428    0.124433
# min      0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.285714    0.136364    0.111111    0.277778    0.001188
# 50%      0.571429    0.454545    0.111111    0.277778    0.001188
# 75%      0.761905    0.727273    0.555556    0.611111    0.133017
# max      1.000000    1.000000    1.000000    1.000000    1.000000
#
#        TRANSMISSAO        PAIS
# count   986.000000  986.000000
# mean      0.456389    0.499887
# std       0.498347    0.319069
# min       0.000000    0.000000
# 25%       0.000000    0.222222
# 50%       0.000000    0.500000
# 75%       1.000000    0.777778
# max       1.000000    1.000000

# %%
# df_dados
# df_padronizado
# df_padronizar

# %%
import seaborn as sns

# %%
df_dados.corr()
# Out:
#                MODELO  KM-LITRO  CILINDROS  PESO(KG)   CAVALOS  TRANSMISSAO  \
# MODELO       1.000000  0.428497  -0.361893 -0.122851 -0.403278     0.607556
# KM-LITRO     0.428497  1.000000  -0.815090  0.034760 -0.788358     0.641490
# CILINDROS   -0.361893 -0.815090   1.000000 -0.311150  0.924733    -0.626354
# PESO(KG)    -0.122851  0.034760  -0.311150  1.000000 -0.382107    -0.121160
# CAVALOS     -0.403278 -0.788358   0.924733 -0.382107  1.000000    -0.616357
# TRANSMISSAO  0.607556  0.641490  -0.626354 -0.121160 -0.616357     1.000000
# PAIS         0.008756 -0.007238   0.009733 -0.013565  0.018298     0.006709
#
#                  PAIS
# MODELO       0.008756
# KM-LITRO    -0.007238
# CILINDROS    0.009733
# PESO(KG)    -0.013565
# CAVALOS      0.018298
# TRANSMISSAO  0.006709
# PAIS         1.000000

# %%
matrix = df_dados.corr()
plt.figure(figsize=(10, 5))
sns.heatmap(matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Matrix de correlação')
plt.show()
