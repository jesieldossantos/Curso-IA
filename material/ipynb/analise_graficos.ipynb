# %% [markdown]
# # 📊 Análise Gráfica de Dados com Pandas, Seaborn e Matplotlib

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Configurar estilo dos gráficos
sns.set(style="whitegrid")

# Carregar a base de dados
df = pd.read_csv('base_dados_graficos.csv')
df.head()
# Out:
#    Idade Gênero     Cidade  Renda Mensal (R$)  Horas de Estudo  \
# 0     56      F   Curitiba               4918              2.4
# 1     46      F  São Paulo               5296              2.8
# 2     32      F   Curitiba               2235              4.6
# 3     60      M  São Paulo               4951              2.6
# 4     25      M  Fortaleza               2348              1.9
#
#   Categoria Profissional  Frequência de Exercícios (semana)  \
# 0           Desempregado                                  2
# 1           Desempregado                                  1
# 2           Desempregado                                  4
# 3             Empresário                                  5
# 4              Professor                                  6
#
#    Alimentação Saudável (%)  Satisfação com a Vida (0-10)
# 0                        10                             9
# 1                       100                             0
# ...

# %% [markdown]
# ## 📊 Histograma — Distribuição de Idades

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df["Idade"], bins=20, kde=False, color="skyblue")
plt.title("Distribuição de Idades")
plt.xlabel("Idade")
plt.ylabel("Frequência")
plt.show()

# %% [markdown]
# ## 🌊 Gráfico de Densidade (KDE) — Renda Mensal

# %%
plt.figure(figsize=(10, 6))
sns.kdeplot(df["Renda Mensal (R$)"], fill=True, color="green")
plt.title("Densidade de Renda Mensal")
plt.xlabel("Renda (R$)")
plt.ylabel("Densidade")
plt.show()

# %% [markdown]
# ## 📦 Boxplot — Renda por Gênero

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x="Gênero", y="Renda Mensal (R$)", data=df, palette="pastel")
plt.title("Boxplot da Renda por Gênero")
plt.xlabel("Gênero")
plt.ylabel("Renda Mensal (R$)")
plt.show()
# Out:
# C:\Users\jesie\AppData\Local\Temp\ipykernel_14208\1136443509.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Gênero", y="Renda Mensal (R$)", data=df, palette="pastel")

# %% [markdown]
# ## 📋 Gráfico de Barras — Categorias Profissionais

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x="Categoria Profissional", data=df, palette="muted",
              order=df["Categoria Profissional"].value_counts().index)
plt.title("Distribuição por Categoria Profissional")
plt.xlabel("Categoria Profissional")
plt.ylabel("Contagem")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\jesie\AppData\Local\Temp\ipykernel_14208\427442093.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="Categoria Profissional", data=df, palette="muted",

# %% [markdown]
# ## 🥧 Gráfico de Pizza — Gênero

# %%
df["Gênero"].value_counts().plot.pie(
    autopct='%1.1f%%',
    colors=["#ff9999", "#66b3ff"],
    figsize=(6, 6),
    startangle=90,
    wedgeprops=dict(width=0.5)
)
plt.title("Distribuição de Gênero")
plt.ylabel("")
plt.show()

# %% [markdown]
# ## 🟡 Gráfico de Dispersão — Idade vs. Satisfação com a Vida

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x="Idade", y="Satisfação com a Vida (0-10)", hue="Gênero", data=df, alpha=0.5)
plt.title("Idade vs. Satisfação com a Vida")
plt.xlabel("Idade")
plt.ylabel("Satisfação com a Vida (0-10)")
plt.show()
# Out:
# c:\Users\jesie\OneDrive\Documentos\jesiel\projetos\Curso-IA\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
